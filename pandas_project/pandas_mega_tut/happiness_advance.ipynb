# %% [markdown]
# # PANDAS MEGA TUTORIAL USING HAPPINESS DATASET

# %% [markdown]
# ![pandas.png](attachment:pandas.png)

# %%
# %matplotlib inline

# %%
import pandas as pd

# %% [markdown]
# ## LOAD DATA

# %%
df = pd.read_csv("world-happiness/2019.csv")

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ## Inspect the data

# %%
df.head(n = 8)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# ...

# %%
df.tail(10)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 146           147                     Haiti  3.597           0.323
# 147           148                  Botswana  3.488           1.041
# 148           149                     Syria  3.462           0.619
# 149           150                    Malawi  3.410           0.191
# 150           151                     Yemen  3.380           0.287
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 146           0.688                    0.449                         0.026
# 147           1.145                    0.538                         0.455
# ...

# %%
df.shape # Shape of our data
# Out:
# (156, 9)

# %%
num_rows, num_cols = df.shape
print(f"There are {num_rows} and {num_cols} cols !")
# Out:
# There are 156 and 9 cols !

# %%
df.dtypes # Data types of our columns
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df.describe() # Describe data (THIS IS METHOD)
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Score"]
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
df["Country or region"]
# Out:
# 0                       Finland
# 1                       Denmark
# 2                        Norway
# 3                       Iceland
# 4                   Netherlands
#                  ...
# 151                      Rwanda
# 152                    Tanzania
# 153                 Afghanistan
# 154    Central African Republic
# 155                 South Sudan
# Name: Country or region, Length: 156, dtype: object

# %%
df["Country or region"].dtype
# Out:
# dtype('O')

# %%
type(df["Country or region"])
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=156, step=1)

# %%
for col in df.columns:
    print(f"{col}: {type(col)}")
# Out:
# Overall rank: <class 'str'>
# Country or region: <class 'str'>
# Score: <class 'str'>
# GDP per capita: <class 'str'>
# Social support: <class 'str'>
# Healthy life expectancy: <class 'str'>
# Freedom to make life choices: <class 'str'>
# Generosity: <class 'str'>
# Perceptions of corruption: <class 'str'>

# %%
for col in df.columns:
    print(f"{col}: {type(df[col])}")
# Out:
# Overall rank: <class 'pandas.core.series.Series'>
# Country or region: <class 'pandas.core.series.Series'>
# Score: <class 'pandas.core.series.Series'>
# GDP per capita: <class 'pandas.core.series.Series'>
# Social support: <class 'pandas.core.series.Series'>
# Healthy life expectancy: <class 'pandas.core.series.Series'>
# Freedom to make life choices: <class 'pandas.core.series.Series'>
# Generosity: <class 'pandas.core.series.Series'>
# Perceptions of corruption: <class 'pandas.core.series.Series'>

# %% [markdown]
# ## What methods and attributes are available in DataFrame?

# %%
dir(df)
# Out:
# ['Generosity',
#  'Score',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %% [markdown]
# ## What methods and attributes are available in Series?

# %%
dir(df["Country or region"])
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %% [markdown]
# ## MAIN POINTS
#
# ### DATAFRAME = the full data, a collection of columns
# ### Series = a single column
# ### A dataframe is collection of series

# %% [markdown]
# ## WHat is min,max and average happiness score ?

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df['Score'].min()
# Out:
# 2.853

# %%
df["Score"].max()
# Out:
# 7.769

# %%
df["Score"].mean()
# Out:
# 5.407096153846153

# %%
df.min()
# Out:
# Overall rank                              1
# Country or region               Afghanistan
# Score                                 2.853
# GDP per capita                          0.0
# Social support                          0.0
# Healthy life expectancy                 0.0
# Freedom to make life choices            0.0
# Generosity                              0.0
# Perceptions of corruption               0.0
# dtype: object

# %%
df.max()
# Out:
# Overall rank                         156
# Country or region               Zimbabwe
# Score                              7.769
# GDP per capita                     1.684
# Social support                     1.624
# Healthy life expectancy            1.141
# Freedom to make life choices       0.631
# Generosity                         0.566
# Perceptions of corruption          0.453
# dtype: object

# %% [markdown]
# ## What is the score for the United States ?

# %%
df["Score"]
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df["Country or region"].value_counts()
# Out:
# Finland                1
# Venezuela              1
# Jordan                 1
# Benin                  1
# Congo (Brazzaville)    1
#                       ..
# Latvia                 1
# South Korea            1
# Estonia                1
# Jamaica                1
# South Sudan            1
# Name: Country or region, Length: 156, dtype: int64

# %%
df["Country or region"] == "Jordan"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Country or region, Length: 156, dtype: bool

# %%
df[(df["Country or region"] == "Jordan")]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 100           101            Jordan  4.906           0.837           1.225
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 100                    0.815                         0.383        0.11
#
#      Perceptions of corruption
# 100                       0.13

# %%
df[(df["Country or region"] == "Jordan")]["Score"]
# Out:
# 100    4.906
# Name: Score, dtype: float64

# %% [markdown]
# ## Option1 Use bracket notation

# %%
# Creates a boolean mask
df["Country or region"] == "United States"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Country or region, Length: 156, dtype: bool

# %%
united_states_mask = df["Country or region"] == "United States"

# %%
df[united_states_mask]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 18            19     United States  6.892           1.433           1.457
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 18                    0.874                         0.454        0.28
#
#     Perceptions of corruption
# 18                      0.128

# %%
df[united_states_mask]["Overall rank"]
# Out:
# 18    19
# Name: Overall rank, dtype: int64

# %%
type(df[united_states_mask]["Overall rank"])
# Out:
# pandas.core.series.Series

# %%
df[united_states_mask]["Score"].values # to get the value ,it will return as numpy
# Out:
# array([6.892])

# %%
df.values
# Out:
# array([[1, 'Finland', 7.769, ..., 0.596, 0.153, 0.393],
#        [2, 'Denmark', 7.6, ..., 0.592, 0.252, 0.41],
#        [3, 'Norway', 7.554, ..., 0.603, 0.271, 0.341],
#        ...,
#        [154, 'Afghanistan', 3.203, ..., 0.0, 0.158, 0.025],
#        [155, 'Central African Republic', 3.083, ..., 0.225, 0.235, 0.035],
#        [156, 'South Sudan', 2.853, ..., 0.01, 0.202, 0.091]], dtype=object)

# %%
df[united_states_mask]["Score"].values[0]
# Out:
# 6.892

# %%
df[united_states_mask]["Score"].iloc[0]
# Out:
# 6.892

# %%
df[united_states_mask]["Overall rank"].iloc[0]
# Out:
# 19

# %% [markdown]
# ## Option_2 Use indices with .iloc and .loc

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# iloc is way to access data in Dataframe by the numeric postion of the rows and columns
df.iloc[22]
# Out:
# Overall rank                        23
# Country or region               Mexico
# Score                            6.595
# GDP per capita                    1.07
# Social support                   1.323
# Healthy life expectancy          0.861
# Freedom to make life choices     0.433
# Generosity                       0.074
# Perceptions of corruption        0.073
# Name: 22, dtype: object

# %%
df.iloc[0]
# Out:
# Overall rank                          1
# Country or region               Finland
# Score                             7.769
# GDP per capita                     1.34
# Social support                    1.587
# Healthy life expectancy           0.986
# Freedom to make life choices      0.596
# Generosity                        0.153
# Perceptions of corruption         0.393
# Name: 0, dtype: object

# %%
df.iloc[0, 1]
# Out:
# 'Finland'

# %%
df.iloc[0, 0]
# Out:
# 1

# %%
df.iloc[0,2]
# Out:
# 7.769

# %%
df.set_index("Country or region")
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Netherlands                          5  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# Rwanda                             152  3.334           0.359           0.711
# Tanzania                           153  3.231           0.476           0.885
# Afghanistan                        154  3.203           0.350           0.517
# Central African Republic           155  3.083           0.026           0.000
# South Sudan                        156  2.853           0.306           0.575
#
# ...

# %%
df_country_index = df.set_index("Country or region")

# %%
df_country_index
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Netherlands                          5  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# Rwanda                             152  3.334           0.359           0.711
# Tanzania                           153  3.231           0.476           0.885
# Afghanistan                        154  3.203           0.350           0.517
# Central African Republic           155  3.083           0.026           0.000
# South Sudan                        156  2.853           0.306           0.575
#
# ...

# %%
df_country_index.loc["Finland"]
# Out:
# Overall rank                    1.000
# Score                           7.769
# GDP per capita                  1.340
# Social support                  1.587
# Healthy life expectancy         0.986
# Freedom to make life choices    0.596
# Generosity                      0.153
# Perceptions of corruption       0.393
# Name: Finland, dtype: float64

# %%
df_country_index.loc["United States"]
# Out:
# Overall rank                    19.000
# Score                            6.892
# GDP per capita                   1.433
# Social support                   1.457
# Healthy life expectancy          0.874
# Freedom to make life choices     0.454
# Generosity                       0.280
# Perceptions of corruption        0.128
# Name: United States, dtype: float64

# %%
df_country_index.loc["United States"]['Score']
# Out:
# 6.892

# %%
df_country_index.loc["United States"]['Overall rank']
# Out:
# 19.0

# %%
df_country_index.iloc[0]
# Out:
# Overall rank                    1.000
# Score                           7.769
# GDP per capita                  1.340
# Social support                  1.587
# Healthy life expectancy         0.986
# Freedom to make life choices    0.596
# Generosity                      0.153
# Perceptions of corruption       0.393
# Name: Finland, dtype: float64

# %%
df_country_index.iloc[0, 2]
# Out:
# 1.34

# %%
# .loc is a way to access data in a dataframe by the name of the index and the name of the column
df_country_index.loc["Ireland","Score"]
# Out:
# 7.021

# %%
df_country_index.loc["Iceland","Score"]
# Out:
# 7.494

# %%
df_country_index.loc["Ireland"]
# Out:
# Overall rank                    16.000
# Score                            7.021
# GDP per capita                   1.499
# Social support                   1.553
# Healthy life expectancy          0.999
# Freedom to make life choices     0.516
# Generosity                       0.298
# Perceptions of corruption        0.310
# Name: Ireland, dtype: float64

# %% [markdown]
# ## QUestion3 - What is the happiest country or country with highest Genreosity Score

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df["Score"].max()
# Out:
# 7.769

# %%
df.sort_values(by="Generosity")
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 81             82            Greece  5.287           1.181           1.156
# 147           148          Botswana  3.488           1.041           1.145
# 89             90        Azerbaijan  5.208           1.043           1.147
# 88             89           Morocco  5.208           0.801           0.782
# 41             42         Lithuania  6.149           1.238           1.515
# ..            ...               ...    ...             ...             ...
# 120           121             Kenya  4.509           0.512           0.983
# 21             22             Malta  6.726           1.300           1.520
# 146           147             Haiti  3.597           0.323           0.688
# 91             92         Indonesia  5.192           0.931           1.203
# 130           131           Myanmar  4.360           0.710           1.181
#
# ...

# %%
df.sort_values(by="Generosity", ascending=False)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 130           131           Myanmar  4.360           0.710           1.181
# 91             92         Indonesia  5.192           0.931           1.203
# 146           147             Haiti  3.597           0.323           0.688
# 21             22             Malta  6.726           1.300           1.520
# 120           121             Kenya  4.509           0.512           0.983
# ..            ...               ...    ...             ...             ...
# 41             42         Lithuania  6.149           1.238           1.515
# 88             89           Morocco  5.208           0.801           0.782
# 89             90        Azerbaijan  5.208           1.043           1.147
# 147           148          Botswana  3.488           1.041           1.145
# 81             82            Greece  5.287           1.181           1.156
#
# ...

# %%
df.sort_values(by="Generosity", ascending=False).head(1)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 130           131           Myanmar   4.36            0.71           1.181
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 130                    0.555                         0.525       0.566
#
#      Perceptions of corruption
# 130                      0.172

# %%
df.sort_values(by="Generosity", ascending=False).iloc[0]
# Out:
# Overall rank                        131
# Country or region               Myanmar
# Score                              4.36
# GDP per capita                     0.71
# Social support                    1.181
# Healthy life expectancy           0.555
# Freedom to make life choices      0.525
# Generosity                        0.566
# Perceptions of corruption         0.172
# Name: 130, dtype: object

# %%
df.sort_values(by="GDP per capita")
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 111           112                   Somalia  4.668           0.000
# 154           155  Central African Republic  3.083           0.026
# 144           145                   Burundi  3.775           0.046
# 140           141                   Liberia  3.975           0.073
# 126           127          Congo (Kinshasa)  4.418           0.094
# ..            ...                       ...    ...             ...
# 50             51                    Kuwait  6.021           1.500
# 20             21      United Arab Emirates  6.825           1.503
# 33             34                 Singapore  6.262           1.572
# 13             14                Luxembourg  7.090           1.609
# 28             29                     Qatar  6.374           1.684
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 111           0.698                    0.268                         0.559
# ...

# %%
df.sort_values(by="GDP per capita", ascending=False)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 28             29                     Qatar  6.374           1.684
# 13             14                Luxembourg  7.090           1.609
# 33             34                 Singapore  6.262           1.572
# 20             21      United Arab Emirates  6.825           1.503
# 50             51                    Kuwait  6.021           1.500
# ..            ...                       ...    ...             ...
# 126           127          Congo (Kinshasa)  4.418           0.094
# 140           141                   Liberia  3.975           0.073
# 144           145                   Burundi  3.775           0.046
# 154           155  Central African Republic  3.083           0.026
# 111           112                   Somalia  4.668           0.000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 28            1.313                    0.871                         0.555
# ...

# %%
df.sort_values(by="GDP per capita", ascending=False).iloc[0]
# Out:
# Overall rank                       29
# Country or region               Qatar
# Score                           6.374
# GDP per capita                  1.684
# Social support                  1.313
# Healthy life expectancy         0.871
# Freedom to make life choices    0.555
# Generosity                       0.22
# Perceptions of corruption       0.167
# Name: 28, dtype: object

# %%
df.sort_values(by="GDP per capita", ascending=False).loc[28] # Index number is 28
# Out:
# Overall rank                       29
# Country or region               Qatar
# Score                           6.374
# GDP per capita                  1.684
# Social support                  1.313
# Healthy life expectancy         0.871
# Freedom to make life choices    0.555
# Generosity                       0.22
# Perceptions of corruption       0.167
# Name: 28, dtype: object

# %%
df.sort_values(by="GDP per capita", ascending=False).loc[28, "Country or region"]
# Out:
# 'Qatar'

# %%
df.sort_values(by="GDP per capita", ascending=False).iloc[0,1]
# Out:
# 'Qatar'

# %% [markdown]
# ## Approach2 -agrmax

# %%
df["Generosity"].argmax() # this returns the index of max genrosity score
# Out:
# 130

# %%
max_gen_index = df["Generosity"].argmax()

# %%
df.iloc[max_gen_index]
# Out:
# Overall rank                        131
# Country or region               Myanmar
# Score                              4.36
# GDP per capita                     0.71
# Social support                    1.181
# Healthy life expectancy           0.555
# Freedom to make life choices      0.525
# Generosity                        0.566
# Perceptions of corruption         0.172
# Name: 130, dtype: object

# %%
df["Score"].argmax()
# Out:
# 0

# %%
df.iloc[0]
# Out:
# Overall rank                          1
# Country or region               Finland
# Score                             7.769
# GDP per capita                     1.34
# Social support                    1.587
# Healthy life expectancy           0.986
# Freedom to make life choices      0.596
# Generosity                        0.153
# Perceptions of corruption         0.393
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Overall rank                          1
# Country or region               Finland
# Score                             7.769
# GDP per capita                     1.34
# Social support                    1.587
# Healthy life expectancy           0.986
# Freedom to make life choices      0.596
# Generosity                        0.153
# Perceptions of corruption         0.393
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ## What does the distribution of happiness score look like

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df['Score'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## What does the distribution of all our columns look like

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Overall rank'}>,
#         <AxesSubplot:title={'center':'Score'}>,
#         <AxesSubplot:title={'center':'GDP per capita'}>],
#        [<AxesSubplot:title={'center':'Social support'}>,
#         <AxesSubplot:title={'center':'Healthy life expectancy'}>,
#         <AxesSubplot:title={'center':'Freedom to make life choices'}>],
#        [<AxesSubplot:title={'center':'Generosity'}>,
#         <AxesSubplot:title={'center':'Perceptions of corruption'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
_ = df.hist()

# %%
_ = df.hist(figsize = (10,10)) # To change height and width columns length

# %% [markdown]
# ## Question 6 - What is the relationship between social support and happiness score ?

# %%
# Plotting relationship between two of the columns
df.plot?  # help way

# %%
df.plot(x = "Social support", y = "Score", title = "RelationShip between social support and happiness")
# Out:
# <AxesSubplot:title={'center':'RelationShip between social support and happiness'}, xlabel='Social support'>

# %%
df.plot(kind = "bar", x = "Social support", y = "Score", title = "RelationShip between social support and happiness")
# Out:
# <AxesSubplot:title={'center':'RelationShip between social support and happiness'}, xlabel='Social support'>

# %%
df.plot(x = "Social support", y = "Score", kind = "scatter", title = "RelationShip between social support and happiness")
# Out:
# <AxesSubplot:title={'center':'RelationShip between social support and happiness'}, xlabel='Social support', ylabel='Score'>

# %% [markdown]
# ## Question7 --> What if we want score to go from 0 to 100,rather than 0 to 10 ?

# %%
df["Score"]
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
df["Score"] * 10
# Out:
# 0      77.69
# 1      76.00
# 2      75.54
# 3      74.94
# 4      74.88
#        ...
# 151    33.34
# 152    32.31
# 153    32.03
# 154    30.83
# 155    28.53
# Name: Score, Length: 156, dtype: float64

# %%
df_copy = df.copy()  # Copying the dataframe and doing the changes

# %%
df_copy
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_copy["Score out of 100"] = df_copy["Score"] * 10

# %%
df_copy
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
#  9   Score out of 100              156 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 12.3+ KB
